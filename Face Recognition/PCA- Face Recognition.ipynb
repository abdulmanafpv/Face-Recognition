# %%
from os import walk,path
import numpy as np
import mahotas as mh
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
X=[]
Y=[]
for dir_path,dir_names,file_names in walk("C:\\Users\\user\\Desktop\\Picture data\\att_faces"):
    print(dir_path)
    print(dir_names)
    print(file_names)

print(X.shape)

print(Y)
# Out:
# C:\Users\user\Desktop\Picture data\att_faces
# ['s1', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18', 's19', 's2', 's20', 's21', 's22', 's23', 's24', 's25', 's26', 's27', 's28', 's29', 's3', 's30', 's31', 's32', 's33', 's34', 's35', 's36', 's37', 's38', 's39', 's4', 's40', 's5', 's6', 's7', 's8', 's9']
# []
# C:\Users\user\Desktop\Picture data\att_faces\s1
# []
# ['1.pgm', '10.pgm', '2.pgm', '3.pgm', '4.pgm', '5.pgm', '6.pgm', '7.pgm', '8.pgm', '9.pgm']
# C:\Users\user\Desktop\Picture data\att_faces\s10
# []
# ['1.pgm', '10.pgm', '2.pgm', '3.pgm', '4.pgm', '5.pgm', '6.pgm', '7.pgm', '8.pgm', '9.pgm']
# C:\Users\user\Desktop\Picture data\att_faces\s11
# []
# ['1.pgm', '10.pgm', '2.pgm', '3.pgm', '4.pgm', '5.pgm', '6.pgm', '7.pgm', '8.pgm', '9.pgm']
# C:\Users\user\Desktop\Picture data\att_faces\s12
# []
# ['1.pgm', '10.pgm', '2.pgm', '3.pgm', '4.pgm', '5.pgm', '6.pgm', '7.pgm', '8.pgm', '9.pgm']
# C:\Users\user\Desktop\Picture data\att_faces\s13
# []
# ...

# %%
for dir_path,dir_names,file_names in walk("C:\\Users\\user\\Desktop\\Picture data\\att_faces"):
    for fn in file_names:
        print(fn)
        if fn[-3:]=='pgm':
            image_filename=path.join(dir_path,fn)
            print(image_filename)
        X.append(scale(mh.imread(image_filename,as_grey=True).reshape(10304).astype('float32')))
        Y.append(dir_path)
# Out:
# 1.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\1.pgm
# 10.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\10.pgm
# 2.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\2.pgm
# 3.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\3.pgm
# 4.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\4.pgm
# 5.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\5.pgm
# 6.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\6.pgm
# 7.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\7.pgm
# 8.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\8.pgm
# 9.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s1\9.pgm
# 1.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s10\1.pgm
# 10.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s10\10.pgm
# 2.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s10\2.pgm
# 3.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s10\3.pgm
# 4.pgm
# C:\Users\user\Desktop\Picture data\att_faces\s10\4.pgm
# 5.pgm
# ...

# %%
X=np.array(X)
print(X.shape)
print(Y)
# Out:
# (400, 10304)
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

pca=PCA(n_components=200)
X_train_reduced=pca.fit_transform(X_train)
X_test_reduced=pca.transform(X_test)
print("The original dim. of the training data were ",X_train.shape)
print("The reduced  dim. of the training data is ",X_train_reduced.shape)
# Out:
# The original dim. of the training data were  (300, 10304)
# The reduced  dim. of the training data is  (300, 200)

# %%
classifier=LogisticRegression()
classifier.fit(X_train_reduced,Y_train)
accuracies=cross_val_score(classifier,X_train_reduced,Y_train)
print("cross validation accuracy :",np.mean(accuracies), accuracies)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
predictions=classifier.predict(X_test_reduced)
print(predictions[2])
print(Y_test[2])
print(classification_report(Y_test,predictions))
# Out:
# C:\Users\user\Desktop\Picture data\att_faces\s12
# C:\Users\user\Desktop\Picture data\att_faces\s12
#                                                   precision    recall  f1-score   support
#
# C:\Users\user\Desktop\Picture data\att_faces\s10       1.00      1.00      1.00         1
# C:\Users\user\Desktop\Picture data\att_faces\s11       1.00      1.00      1.00         2
# C:\Users\user\Desktop\Picture data\att_faces\s12       1.00      1.00      1.00         3
# C:\Users\user\Desktop\Picture data\att_faces\s13       1.00      1.00      1.00         2
# C:\Users\user\Desktop\Picture data\att_faces\s14       1.00      1.00      1.00         4
# C:\Users\user\Desktop\Picture data\att_faces\s15       1.00      1.00      1.00         3
# C:\Users\user\Desktop\Picture data\att_faces\s16       1.00      1.00      1.00         3
# C:\Users\user\Desktop\Picture data\att_faces\s17       1.00      1.00      1.00         2
# ...

# %%
for i,j in enumerate(predictions):
    print("y actual:",Y_test[i])
    print("predicted:",j)
# Out:
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s15
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s15
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s38
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s38
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s12
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s12
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s35
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s40
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s5
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s5
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s8
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s8
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s16
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s16
# y actual: C:\Users\user\Desktop\Picture data\att_faces\s14
# predicted: C:\Users\user\Desktop\Picture data\att_faces\s14
# ...

# %%
import matplotlib.pyplot as plt
pc_values=np.arange(pca.n_components_) + 1
plt.plot(pc_values,pca.explained_variance_ratio_,'o-',linewidth=2,color='blue')
plt.title('screen plot')
plt.xlabel('principal component')
plt.ylabel('variance explained')
plt.show()
